# %%
 x_box = list()
y_box = list()
txt_box = list() # 최기화

for v in page_info:
    crdi,txt = v
    print(crdi,txt)
    x0,y0,x1,y1 = crdi
    new_x, new_y ,new_txt= x0, y0, txt 
    if len(y_box) != 0: 
        old_x, old_y, old_txt = x_box[-1], y_box[-1], txt_box[-1] # history
        if old_y == new_y and old_x > new_x : 
            # swap old <->new loction changes
            print(old_y,new_y)
            x_box[-1], new_x, txt_box[-1] = new_x, x_box[-1],new_txt
            print(new_x)
        elif old_y == new_y and new_y == y1 : # y0랑 y_0-1 같고 
            print('a')
        x_box.append(new_x)
        y_box.append(new_y)
        print()
#         dic_box[i] = []

# %%
box = list()
# y_box = list()
txt_box = list() # 최기화

for coor,txt in page_info:
    new_txt = txt
    new_coor = coor
    if len(box) == 0: 
        box.append(coor)
        txt_box.append(txt)
#         print(box,txt_box)
    else:
        print(box[-1],txt_box[-1])
        old_txt = txt_box[-1] # history
        old_x0, old_y0, old_x1, old_y1 = box[-1] # history
        
        if old_y0 == new_coor[1] and old_x0 > new_coor[0] : 
            print('1',box[-1],txt_box[-1], new_txt)
            
            box[-1],txt_box[-1] = new_coor,new_txt
            print('2',box[-1],txt_box[-1], new_txt)
            
    if old_y == coor[1] and old_y1 == coor[-1] : # y0랑 y_0-1 같고 
        print('a')      

    box.append(new_coor)
    txt_box.append(new_txt)
    print()

# %%
box = list()
# y_box = list()
txt_box = list() # 최기화

for coor,txt in page_info:
    new_txt = txt
    new_coor = coor
    if len(box) == 0: 
        box.append(coor)
        txt_box.append(txt)
#         print(box,txt_box)
    else:
        old_x0, old_y0, old_x1, old_y1 = box[-1] # history
        old_txt = txt_box[-1] # history
        if old_y1 == coor[-1] and old_y0 == coor[1]:
            
            print(box[-1],txt_box[-1])
            print(new_coor,new_txt)
            print()
            if old_x0 < coor[0]:
                print('old',box[-1],txt_box[-1])
                joinTxt = txt_box[-1]+' '+new_txt
                print('Join >>',joinTxt)
                # 병합 
            elif old_x0 > coor[0]:
#             else:
#                 box[-1],txt_box[-1] = new_coor,new_txt
                new_coor,new_txt = box[-1],txt_box[-1]
                joinTxt = txt_box[-1]+' '+new_txt
                print(joinTxt)
#                 print('new',new_coor,new_txt)
                
            # 병합 
            
#         if old_y0 == new_coor[1] and old_x0 > new_coor[0] : 
#             print('1',box[-1],txt_box[-1], new_txt)
            
#             box[-1],txt_box[-1] = new_coor,new_txt
#             print('2',box[-1],txt_box[-1], new_txt)
            
#     if old_y == coor[1] and old_y1 == coor[-1] : # y0랑 y_0-1 같고 
#         print('a')      

    box.append(new_coor)
    txt_box.append(new_txt)
    print()

# %%
box = list()
y_box = list()
txt_box = list() # 최기화

for coor,txt in page_info:
    new_txt = txt
    new_coor = coor
    if len(box) == 0: 
        box.append(coor)
        txt_box.append(txt)
    else:
        old_x0, old_y0, old_x1, old_y1 = box[-1] # history
        old_txt = txt_box[-1] # history
        if old_y1 == coor[-1] and old_y0 == coor[1]:
            
            print(box[-1],txt_box[-1])
            print(new_coor,new_txt)
            print()
            if old_x0 < coor[0]:
                print('old',box[-1],txt_box[-1])
                joinTxt = txt_box[-1]+' '+new_txt
                print('Join >>',joinTxt)
                # 병합 
            else:
                print('new',new_coor,new_txt)
                
            # 병합 
            
#         if old_y0 == new_coor[1] and old_x0 > new_coor[0] : 
#             print('1',box[-1],txt_box[-1], new_txt)
            
#             box[-1],txt_box[-1] = new_coor,new_txt
#             print('2',box[-1],txt_box[-1], new_txt)
            
#     if old_y == coor[1] and old_y1 == coor[-1] : # y0랑 y_0-1 같고 
#         print('a')      

    box.append(new_coor)
    txt_box.append(new_txt)
    print()
