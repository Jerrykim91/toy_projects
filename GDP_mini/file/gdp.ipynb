# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9609-0806
#
#  C:\toy_projects\GDP_mini\file 디렉터리
#
# 2021-03-29  오후 03:46    <DIR>          .
# 2021-03-29  오후 03:46    <DIR>          ..
# 2021-03-29  오후 03:44    <DIR>          .ipynb_checkpoints
# 2021-03-26  오전 12:00             4,745 crwaling.py
# 2021-03-24  오후 11:04               917 csv_to_Mongo.py
# 2021-03-24  오전 12:44             1,357 csv_to_Mongo_gdp.py
# 2021-03-25  오후 11:59             2,269 csv_to_Mongo_pop.py
# 2021-03-24  오전 12:44             2,129 csv_to_oracle.py
# 2021-03-24  오전 12:44             3,551 csv_to_oracle_pop.py
# 2021-03-25  오후 11:39             6,697 error.py
# 2021-03-24  오전 12:44           249,996 GDP.csv
# 2021-03-29  오후 03:46           126,178 gdp.ipynb
# 2021-03-25  오후 11:58            99,332 pop.ipynb
# 2021-03-24  오전 12:44           175,665 Population.csv
#               11개 파일             672,836 바이트
#                3개 디렉터리  70,968,377,344 바이트 남음

# %%
# pip list

# %%
import pandas as pd
import os, glob

# %%
path = 'C:/data/%s.xlsx' 
df_gdp = pd.read_excel(path %'GDP', header=4)
df_gdp.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
df_gdp.tail()
# Out:
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 262        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 263      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09  1.037400e+10
# 262  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08  8.394286e+08
# 263  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09  1.217138e+09
#
#              1965  ...          2010          2011          2012  \
# ...

# %%
df_gdp.shape
# Out:
# (264, 64)

# %%
df_gdp.columns[5]
# Out:
# 1961

# %% [markdown]
# 이제 어떻게 할건지 알아야 한다,
# no, CountryName, gdp_year

# %%
df_gdp.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                    1960,             1961,             1962,             1963,
#                    1964,             1965,             1966,             1967,
#                    1968,             1969,             1970,             1971,
#                    1972,             1973,             1974,             1975,
#                    1976,             1977,             1978,             1979,
#                    1980,             1981,             1982,             1983,
#                    1984,             1985,             1986,             1987,
#                    1988,             1989,             1990,             1991,
#                    1992,             1993,             1994,             1995,
#                    1996,             1997,             1998,             1999,
#                    2000,             2001,             2002,             2003,
# ...

# %%
# 사본 만들기
df_test = df_gdp

# %%
test = df_gdp.columns[1:4]
df_test= df_test.drop(test,axis=1)

# %%
df_test
# Out:
#      Country Name          1960          1961          1962          1963  \
# 0           Aruba           NaN           NaN           NaN           NaN
# 1     Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2          Angola           NaN           NaN           NaN           NaN
# 3         Albania           NaN           NaN           NaN           NaN
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo           NaN           NaN           NaN           NaN
# 260   Yemen, Rep.           NaN           NaN           NaN           NaN
# 261  South Africa  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# 262        Zambia  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 263      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#              1964          1965          1966          1967          1968  \
# ...

# %%
df_test.iloc[:,:1]
# Out:
#      Country Name
# 0           Aruba
# 1     Afghanistan
# 2          Angola
# 3         Albania
# 4         Andorra
# ..            ...
# 259        Kosovo
# 260   Yemen, Rep.
# 261  South Africa
# 262        Zambia
# 263      Zimbabwe
#
# [264 rows x 1 columns]

# %%
extract_col = df_test.iloc[:,:1]+df_test.iloc[:,1:].add_prefix('gdp_')

# %%
extract_col.columns
# Out:
# Index(['Country Name', 'gdp_1960', 'gdp_1961', 'gdp_1962', 'gdp_1963',
#        'gdp_1964', 'gdp_1965', 'gdp_1966', 'gdp_1967', 'gdp_1968', 'gdp_1969',
#        'gdp_1970', 'gdp_1971', 'gdp_1972', 'gdp_1973', 'gdp_1974', 'gdp_1975',
#        'gdp_1976', 'gdp_1977', 'gdp_1978', 'gdp_1979', 'gdp_1980', 'gdp_1981',
#        'gdp_1982', 'gdp_1983', 'gdp_1984', 'gdp_1985', 'gdp_1986', 'gdp_1987',
#        'gdp_1988', 'gdp_1989', 'gdp_1990', 'gdp_1991', 'gdp_1992', 'gdp_1993',
#        'gdp_1994', 'gdp_1995', 'gdp_1996', 'gdp_1997', 'gdp_1998', 'gdp_1999',
#        'gdp_2000', 'gdp_2001', 'gdp_2002', 'gdp_2003', 'gdp_2004', 'gdp_2005',
#        'gdp_2006', 'gdp_2007', 'gdp_2008', 'gdp_2009', 'gdp_2010', 'gdp_2011',
#        'gdp_2012', 'gdp_2013', 'gdp_2014', 'gdp_2015', 'gdp_2016', 'gdp_2017',
#        'gdp_2018', 'gdp_2019'],
#       dtype='object')

# %%
df_test.columns=['Country Name', 'gdp_1960', 'gdp_1961', 'gdp_1962', 'gdp_1963',
       'gdp_1964', 'gdp_1965', 'gdp_1966', 'gdp_1967', 'gdp_1968', 'gdp_1969',
       'gdp_1970', 'gdp_1971', 'gdp_1972', 'gdp_1973', 'gdp_1974', 'gdp_1975',
       'gdp_1976', 'gdp_1977', 'gdp_1978', 'gdp_1979', 'gdp_1980', 'gdp_1981',
       'gdp_1982', 'gdp_1983', 'gdp_1984', 'gdp_1985', 'gdp_1986', 'gdp_1987',
       'gdp_1988', 'gdp_1989', 'gdp_1990', 'gdp_1991', 'gdp_1992', 'gdp_1993',
       'gdp_1994', 'gdp_1995', 'gdp_1996', 'gdp_1997', 'gdp_1998', 'gdp_1999',
       'gdp_2000', 'gdp_2001', 'gdp_2002', 'gdp_2003', 'gdp_2004', 'gdp_2005',
       'gdp_2006', 'gdp_2007', 'gdp_2008', 'gdp_2009', 'gdp_2010', 'gdp_2011',
       'gdp_2012', 'gdp_2013', 'gdp_2014', 'gdp_2015', 'gdp_2016', 'gdp_2017',
       'gdp_2018', 'gdp_2019']

# %%
df_test
# Out:
#      Country Name      gdp_1960      gdp_1961      gdp_1962      gdp_1963  \
# 0           Aruba           NaN           NaN           NaN           NaN
# 1     Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2          Angola           NaN           NaN           NaN           NaN
# 3         Albania           NaN           NaN           NaN           NaN
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo           NaN           NaN           NaN           NaN
# 260   Yemen, Rep.           NaN           NaN           NaN           NaN
# 261  South Africa  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# 262        Zambia  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 263      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#          gdp_1964      gdp_1965      gdp_1966      gdp_1967      gdp_1968  \
# ...

# %%
df_test['no'] = 0

# %%
for i in range(0,265):
    df_test['no'][i] = i+1

print(df_test)
# Out:
#      Country Name      gdp_1960      gdp_1961      gdp_1962      gdp_1963  \
# 0           Aruba           NaN           NaN           NaN           NaN
# 1     Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2          Angola           NaN           NaN           NaN           NaN
# 3         Albania           NaN           NaN           NaN           NaN
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo           NaN           NaN           NaN           NaN
# 260   Yemen, Rep.           NaN           NaN           NaN           NaN
# 261  South Africa  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# 262        Zambia  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 263      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#          gdp_1964      gdp_1965      gdp_1966      gdp_1967      gdp_1968  \
# ...

# %%
df_test
# Out:
#      Country Name      gdp_1960      gdp_1961      gdp_1962      gdp_1963  \
# 0           Aruba           NaN           NaN           NaN           NaN
# 1     Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 2          Angola           NaN           NaN           NaN           NaN
# 3         Albania           NaN           NaN           NaN           NaN
# 4         Andorra           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 259        Kosovo           NaN           NaN           NaN           NaN
# 260   Yemen, Rep.           NaN           NaN           NaN           NaN
# 261  South Africa  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# 262        Zambia  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 263      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#          gdp_1964      gdp_1965      gdp_1966      gdp_1967      gdp_1968  \
# ...

# %%
df_test=df_test[['no','Country Name', 'gdp_1960', 'gdp_1961', 'gdp_1962', 'gdp_1963',
       'gdp_1964', 'gdp_1965', 'gdp_1966', 'gdp_1967', 'gdp_1968', 'gdp_1969',
       'gdp_1970', 'gdp_1971', 'gdp_1972', 'gdp_1973', 'gdp_1974', 'gdp_1975',
       'gdp_1976', 'gdp_1977', 'gdp_1978', 'gdp_1979', 'gdp_1980', 'gdp_1981',
       'gdp_1982', 'gdp_1983', 'gdp_1984', 'gdp_1985', 'gdp_1986', 'gdp_1987',
       'gdp_1988', 'gdp_1989', 'gdp_1990', 'gdp_1991', 'gdp_1992', 'gdp_1993',
       'gdp_1994', 'gdp_1995', 'gdp_1996', 'gdp_1997', 'gdp_1998', 'gdp_1999',
       'gdp_2000', 'gdp_2001', 'gdp_2002', 'gdp_2003', 'gdp_2004', 'gdp_2005',
       'gdp_2006', 'gdp_2007', 'gdp_2008', 'gdp_2009', 'gdp_2010', 'gdp_2011',
       'gdp_2012', 'gdp_2013', 'gdp_2014', 'gdp_2015', 'gdp_2016', 'gdp_2017',
       'gdp_2018', 'gdp_2019']]

# %%
df_test
# Out:
#       no  Country Name      gdp_1960      gdp_1961      gdp_1962  \
# 0      1         Aruba           NaN           NaN           NaN
# 1      2   Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08
# 2      3        Angola           NaN           NaN           NaN
# 3      4       Albania           NaN           NaN           NaN
# 4      5       Andorra           NaN           NaN           NaN
# ..   ...           ...           ...           ...           ...
# 259  260        Kosovo           NaN           NaN           NaN
# 260  261   Yemen, Rep.           NaN           NaN           NaN
# 261  262  South Africa  7.575397e+09  7.972997e+09  8.497997e+09
# 262  263        Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 263  264      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
#          gdp_1963      gdp_1964      gdp_1965      gdp_1966      gdp_1967  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
# df_test.T

# %%
print(df_test.dtypes)
# Out:
# no                int64
# Country Name     object
# gdp_1960        float64
# gdp_1961        float64
# gdp_1962        float64
#                  ...
# gdp_2015        float64
# gdp_2016        float64
# gdp_2017        float64
# gdp_2018        float64
# gdp_2019        float64
# Length: 62, dtype: object

# %%
# a = df_test.T

# %%
# print(a.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-622f7f275295> in <module>
# ----> 1 print(a.dtypes)
#
# NameError: name 'a' is not defined

# %%
# df_test=df_test.transpose()

# %%
# 'Country Name'라인 인덱스 추출
df_test.iloc[0,:]
# Out:
# no                        1
# Country Name          Aruba
# gdp_1960                NaN
# gdp_1961                NaN
# gdp_1962                NaN
#                    ...
# gdp_2015        2.69162e+09
# gdp_2016        2.64693e+09
# gdp_2017        2.70056e+09
# gdp_2018                NaN
# gdp_2019                NaN
# Name: 0, Length: 62, dtype: object

# %%
df_test.info
# Out:
# <bound method DataFrame.info of       no  Country Name      gdp_1960      gdp_1961      gdp_1962  \
# 0      1         Aruba           NaN           NaN           NaN
# 1      2   Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08
# 2      3        Angola           NaN           NaN           NaN
# 3      4       Albania           NaN           NaN           NaN
# 4      5       Andorra           NaN           NaN           NaN
# ..   ...           ...           ...           ...           ...
# 259  260        Kosovo           NaN           NaN           NaN
# 260  261   Yemen, Rep.           NaN           NaN           NaN
# 261  262  South Africa  7.575397e+09  7.972997e+09  8.497997e+09
# 262  263        Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 263  264      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
#          gdp_1963      gdp_1964      gdp_1965      gdp_1966      gdp_1967  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
df_test = df_test.fillna(0)

# %%
df_test.info
# Out:
# <bound method DataFrame.info of       no  Country Name      gdp_1960      gdp_1961      gdp_1962  \
# 0      1         Aruba  0.000000e+00  0.000000e+00  0.000000e+00
# 1      2   Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08
# 2      3        Angola  0.000000e+00  0.000000e+00  0.000000e+00
# 3      4       Albania  0.000000e+00  0.000000e+00  0.000000e+00
# 4      5       Andorra  0.000000e+00  0.000000e+00  0.000000e+00
# ..   ...           ...           ...           ...           ...
# 259  260        Kosovo  0.000000e+00  0.000000e+00  0.000000e+00
# 260  261   Yemen, Rep.  0.000000e+00  0.000000e+00  0.000000e+00
# 261  262  South Africa  7.575397e+09  7.972997e+09  8.497997e+09
# 262  263        Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 263  264      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
#          gdp_1963      gdp_1964      gdp_1965      gdp_1966      gdp_1967  \
# 0    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
# data = [ i for i in a.iloc[0,:]]

# %%
# data

# %%
df_test
# Out:
#       no  Country Name      gdp_1960      gdp_1961      gdp_1962  \
# 0      1         Aruba  0.000000e+00  0.000000e+00  0.000000e+00
# 1      2   Afghanistan  5.377778e+08  5.488889e+08  5.466667e+08
# 2      3        Angola  0.000000e+00  0.000000e+00  0.000000e+00
# 3      4       Albania  0.000000e+00  0.000000e+00  0.000000e+00
# 4      5       Andorra  0.000000e+00  0.000000e+00  0.000000e+00
# ..   ...           ...           ...           ...           ...
# 259  260        Kosovo  0.000000e+00  0.000000e+00  0.000000e+00
# 260  261   Yemen, Rep.  0.000000e+00  0.000000e+00  0.000000e+00
# 261  262  South Africa  7.575397e+09  7.972997e+09  8.497997e+09
# 262  263        Zambia  7.130000e+08  6.962857e+08  6.931429e+08
# 263  264      Zimbabwe  1.052990e+09  1.096647e+09  1.117602e+09
#
#          gdp_1963      gdp_1964      gdp_1965      gdp_1966      gdp_1967  \
# 0    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
pathName = 'C:\data\%s' 
df_test.to_csv('C:/data/%s.csv'% f'gdp', index=None, header=None, mode='w', encoding='utf-8')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 62 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   no            264 non-null    int64
#  1   Country Name  264 non-null    object
#  2   gdp_1960      264 non-null    float64
#  3   gdp_1961      264 non-null    float64
#  4   gdp_1962      264 non-null    float64
#  5   gdp_1963      264 non-null    float64
#  6   gdp_1964      264 non-null    float64
#  7   gdp_1965      264 non-null    float64
#  8   gdp_1966      264 non-null    float64
#  9   gdp_1967      264 non-null    float64
#  10  gdp_1968      264 non-null    float64
#  11  gdp_1969      264 non-null    float64
#  12  gdp_1970      264 non-null    float64
#  13  gdp_1971      264 non-null    float64
#  14  gdp_1972      264 non-null    float64
#  15  gdp_1973      264 non-null    float64
#  16  gdp_1974      264 non-null    float64
# ...

# %%
print(df_gdp.dtypes)
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Length: 64, dtype: object

# %%
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 62 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   no            264 non-null    int64
#  1   Country Name  264 non-null    object
#  2   gdp_1960      264 non-null    float64
#  3   gdp_1961      264 non-null    float64
#  4   gdp_1962      264 non-null    float64
#  5   gdp_1963      264 non-null    float64
#  6   gdp_1964      264 non-null    float64
#  7   gdp_1965      264 non-null    float64
#  8   gdp_1966      264 non-null    float64
#  9   gdp_1967      264 non-null    float64
#  10  gdp_1968      264 non-null    float64
#  11  gdp_1969      264 non-null    float64
#  12  gdp_1970      264 non-null    float64
#  13  gdp_1971      264 non-null    float64
#  14  gdp_1972      264 non-null    float64
#  15  gdp_1973      264 non-null    float64
#  16  gdp_1974      264 non-null    float64
# ...

# %%
float64
